# %%
from graphics import rectangle
from graphics import area
from graphics.Graphics3D import cuboid
from graphics.Graphics3D import sphere

while True:
    print("1. Rectangle\n2. Circle\n3. Cuboid\n4. Sphere\n5. Exit")
    ch = int(input("Enter your choice: "))

    if ch == 1:
        l = int(input("Enter length: "))
        b = int(input("Enter breadth: "))
        rectangle.rectarea(l, b)
        rectangle.rectperi(l, b)

    elif ch == 2:
        r = int(input("Enter radius: "))
        area.circlearea(r)
        area.circleperi(r)

    elif ch == 3:
        l = int(input("Enter length: "))
        b = int(input("Enter breadth: "))
        h = int(input("Enter height: "))
        cuboid.cuboidarea(l, b, h)
        cuboid.cuboidperi(l, b, h)

    elif ch == 4:
        r = int(input("Enter radius: "))
        sphere.spherearea(r)
        sphere.sphereperi(r)

    elif ch == 5:
        print("Exiting...")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# 1. Rectangle
# 2. Circle
# 3. Cuboid
# 4. Sphere
# 5. Exit
# Enter your choice: 2
# Enter radius: 5
# Area of Circle:  78.5
# Perimeter of circle:  31.400000000000002
# 1. Rectangle
# 2. Circle
# 3. Cuboid
# 4. Sphere
# 5. Exit
# Enter your choice: 1
# Enter length: 23
# Enter breadth: 22
# Area of Rectangle:  506
# Perimeter of rectangle:  90
# 1. Rectangle
# 2. Circle
# 3. Cuboid
# 4. Sphere
# 5. Exit
# Enter your choice: 3
# Enter length: 23
# Enter breadth: 45
# Enter height: 4
# Area of cuboid:  2614
# Perimeter of cuboid:  288
# 1. Rectangle
# 2. Circle
# 3. Cuboid
# 4. Sphere
# 5. Exit
# Enter your choice: 4
# Enter radius: 34
# Area of sphere:  7259.68
# Perimeter of sphere:  14519.36
# 1. Rectangle
# 2. Circle
# 3. Cuboid
# 4. Sphere
# 5. Exit
